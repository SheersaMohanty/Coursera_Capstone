# %% [markdown]
# # Business Problem

# %% [markdown]
# #### In my project, I am going to take two cities of India - Bangalore and Kolkata. My client is looking to open a restaurant in one of these cities. With the help of Foursquare location data, we are going to find out which city is likely to be more financially beneficial to my client in terms of the returns on investment.

# %% [markdown]
# ## Data

# %% [markdown]
# #### We are going to consider the population density and the various age groups which are present in the population. We
